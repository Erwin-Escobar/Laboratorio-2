# %% [markdown]
# ### Problema #1: Binarización de una imagen

# %%
import cv2
import matplotlib.pyplot as plt

def binarizar_imagen(imagen, umbral=127):
    # Convertir la imagen a escala de grises
    imagen_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
    
    # Aplicar binarización
    _, imagen_binarizada = cv2.threshold(imagen_gris, umbral, 255, cv2.THRESH_BINARY)
    
    # Guardar la imagen binarizada
    cv2.imwrite(r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen_binarizada.jpg", imagen_binarizada)
    
    # Mostrar la imagen binarizada
    plt.imshow(imagen_binarizada, cmap='gray')
    plt.title('Imagen Binarizada')
    plt.axis('off')
    plt.show()

# Cargar la imagen desde el archivo
ruta_imagen = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen.jpg"
imagen = cv2.imread(ruta_imagen)
binarizar_imagen(imagen)

# %%
def resize_images(imagen1, imagen2):
    # Redimensionar la imagen2 al tamaño de imagen1
    tamaño_imagen1 = (imagen1.shape[1], imagen1.shape[0])
    imagen2_redimensionada = cv2.resize(imagen2, tamaño_imagen1, interpolation=cv2.INTER_AREA)
    return imagen2_redimensionada

def operaciones_imagenes(imagen1, imagen2, umbral=127):
    # Redimensionar las imágenes para que tengan el mismo tamaño
    imagen2 = resize_images(imagen1, imagen2)
    
    # Convertir a escala de grises
    img1_gray = cv2.cvtColor(imagen1, cv2.COLOR_BGR2GRAY)
    img2_gray = cv2.cvtColor(imagen2, cv2.COLOR_BGR2GRAY)
    
    # Binarizar las imágenes
    _, img1_bin = cv2.threshold(img1_gray, umbral, 255, cv2.THRESH_BINARY)
    _, img2_bin = cv2.threshold(img2_gray, umbral, 255, cv2.THRESH_BINARY)
    
    # Operaciones aritméticas y lógicas
    suma = cv2.add(img1_bin, img2_bin)
    resta = cv2.subtract(img1_bin, img2_bin)
    and_img = cv2.bitwise_and(img1_bin, img2_bin)
    or_img = cv2.bitwise_or(img1_bin, img2_bin)
    xor_img = cv2.bitwise_xor(img1_bin, img2_bin)
    
    # Mostrar los resultados
    titulos = ['Suma', 'Resta', 'AND', 'OR', 'XOR']
    imagenes = [suma, resta, and_img, or_img, xor_img]
    
    plt.figure(figsize=(15, 5))
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(imagenes[i], cmap='gray')
        plt.title(titulos[i])
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Cargar dos imágenes usando rutas absolutas
ruta_imagen1 = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen1.jpg"
ruta_imagen2 = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen2.jpeg"

imagen1 = cv2.imread(ruta_imagen1)
imagen2 = cv2.imread(ruta_imagen2)

# Realizar operaciones
operaciones_imagenes(imagen1, imagen2)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def mostrar_imagen_3D(imagen_gris):
    h, w = imagen_gris.shape
    X, Y = np.meshgrid(range(w), range(h))
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, imagen_gris, cmap='gray')
    plt.show()

# Cargar la imagen en escala de grises
imagen = cv2.imread('ruta_a_tu_imagen.jpg', cv2.IMREAD_GRAYSCALE)
mostrar_imagen_3D(imagen)

# %%
import cv2
import matplotlib.pyplot as plt

def resize_images(imagen1, imagen2):
    # Redimensionar la imagen2 al tamaño de imagen1
    tamaño_imagen1 = (imagen1.shape[1], imagen1.shape[0])
    imagen2_redimensionada = cv2.resize(imagen2, tamaño_imagen1, interpolation=cv2.INTER_AREA)
    return imagen2_redimensionada

def operaciones_imagenes(imagen1, imagen2, umbral=127):
    # Redimensionar las imágenes para que tengan el mismo tamaño
    imagen2 = resize_images(imagen1, imagen2)
    
    # Convertir a escala de grises
    img1_gray = cv2.cvtColor(imagen1, cv2.COLOR_BGR2GRAY)
    img2_gray = cv2.cvtColor(imagen2, cv2.COLOR_BGR2GRAY)
    
    # Binarizar las imágenes
    _, img1_bin = cv2.threshold(img1_gray, umbral, 255, cv2.THRESH_BINARY)
    _, img2_bin = cv2.threshold(img2_gray, umbral, 255, cv2.THRESH_BINARY)
    
    # Operaciones aritméticas y lógicas
    suma = cv2.add(img1_bin, img2_bin)
    resta = cv2.subtract(img1_bin, img2_bin)
    and_img = cv2.bitwise_and(img1_bin, img2_bin)
    or_img = cv2.bitwise_or(img1_bin, img2_bin)
    xor_img = cv2.bitwise_xor(img1_bin, img2_bin)
    
    # Mostrar los resultados
    titulos = ['Suma', 'Resta', 'AND', 'OR', 'XOR']
    imagenes = [suma, resta, and_img, or_img, xor_img]
    
    plt.figure(figsize=(15, 5))
    for i in range(5):
        plt.subplot(1, 5, i + 1)
        plt.imshow(imagenes[i], cmap='gray')
        plt.title(titulos[i])
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Cargar dos imágenes usando rutas absolutas
ruta_imagen1 = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen1.jpg"
ruta_imagen2 = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen2.jpeg"

imagen1 = cv2.imread(ruta_imagen1)
imagen2 = cv2.imread(ruta_imagen2)

# Verificar que las imágenes se cargaron correctamente
if imagen1 is None or imagen2 is None:
    print("Error al cargar una o ambas imágenes.")
else:
    # Realizar operaciones
    operaciones_imagenes(imagen1, imagen2)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def mostrar_imagen_3d(imagen):
    # Convertir la imagen a escala de grises si no lo está
    if len(imagen.shape) == 3:
        imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
    
    # Obtener las dimensiones de la imagen
    alto, ancho = imagen.shape
    x = np.arange(0, ancho)
    y = np.arange(0, alto)
    x, y = np.meshgrid(x, y)
    
    # Crear la figura y el eje 3D
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    # Graficar la superficie
    ax.plot_surface(x, y, imagen, cmap='gray', edgecolor='none')
    
    # Etiquetas de los ejes
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Intensidad de Gris')
    ax.set_title('Imagen en 3D')
    
    # Mostrar la gráfica
    plt.show()

# Cargar la imagen en escala de grises
ruta_imagen = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen.jpg"
imagen = cv2.imread(ruta_imagen, cv2.IMREAD_GRAYSCALE)

# Mostrar la imagen en 3D
mostrar_imagen_3d(imagen)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def transformacion_negativa(imagen):
    # Transformación negativa
    imagen_negativa = 255 - imagen
    return imagen_negativa

def transformacion_lineal(imagen, a=1.0, b=0):
    # Transformación lineal
    imagen_lineal = cv2.convertScaleAbs(imagen, alpha=a, beta=b)
    return imagen_lineal

def transformacion_logaritmica(imagen, c=255):
    # Transformación logarítmica
    imagen_log = c * np.log1p(imagen.astype(np.float32) / 255.0)
    imagen_log = cv2.normalize(imagen_log, None, 0, 255, cv2.NORM_MINMAX)
    imagen_log = np.uint8(imagen_log)
    return imagen_log

def transformacion_exponencial(imagen, gamma=1.0):
    # Transformación exponencial
    imagen_exp = np.power(imagen / 255.0, gamma) * 255
    imagen_exp = np.uint8(imagen_exp)
    return imagen_exp

def mostrar_imagenes(imagenes, titulos):
    plt.figure(figsize=(15, 10))
    for i, (img, titulo) in enumerate(zip(imagenes, titulos)):
        plt.subplot(2, 2, i + 1)
        plt.imshow(img, cmap='gray')
        plt.title(titulo)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Cargar la imagen en escala de grises
ruta_imagen = r"C:\Users\egesc\OneDrive - Universidad Galileo\2024\Trimestre 3\TEXT MINING & IMAGE RECOGNITION\Proyecto_2\imagen.jpg"
imagen = cv2.imread(ruta_imagen, cv2.IMREAD_GRAYSCALE)

# Aplicar transformaciones
imagen_negativa = transformacion_negativa(imagen)
imagen_lineal = transformacion_lineal(imagen)
imagen_logaritmica = transformacion_logaritmica(imagen)
imagen_exponencial = transformacion_exponencial(imagen)

# Mostrar todas las imágenes transformadas
imagenes = [imagen_negativa, imagen_lineal, imagen_logaritmica, imagen_exponencial]
titulos = ['Negativa', 'Lineal', 'Logarítmica', 'Exponencial']

mostrar_imagenes(imagenes, titulos)

# %% [markdown]
# ### Problema #5

# %% [markdown]
# ## Kernel Laplaciano (Laplacian Kernel)
# ### Descripción:
# El Laplaciano es un operador de detección de bordes que utiliza un kernel para encontrar áreas de cambio rápido en la intensidad de la imagen, como los bordes.
# * Kernel: El kernel Laplaciano más común es una matriz de 3x3.
# ### Características:
# * Detección de Bordes: Resalta los bordes al encontrar las áreas donde hay un cambio significativo en la intensidad.
# * No es Direccional: No tiene preferencia por una dirección específica de los bordes, ya que considera los cambios en todas las direcciones.
# * Ruido: Puede ser sensible al ruido, ya que el Laplaciano es una segunda derivada que amplifica el ruido en la imagen.
# Aplicación:
#
# ### Convolución:
# Se aplica el kernel Laplaciano a la imagen mediante la operación de convolución para obtener la imagen de salida.
# ### Algoritmo de Canny
# ### Descripción:
# El algoritmo de Canny es un enfoque más sofisticado y robusto para la detección de bordes que utiliza varios pasos para detectar bordes en una imagen.
#
# Pasos del Algoritmo de Canny:
#
# * Filtrado: Aplica un filtro gaussiano para suavizar la imagen y reducir el ruido.
# * Gradiente: Calcula el gradiente de intensidad en cada píxel para encontrar las magnitudes y direcciones de los bordes.
# * Supresión de No Máximos: Elimina los píxeles que no son máximos locales en la dirección del gradiente, afinando así los bordes.
# * Histeresis: Utiliza dos umbrales para decidir si un píxel es parte de un borde o no, con un umbral alto para detectar bordes fuertes y un umbral bajo para conectarlos.
#
# ### Características:
#
# * Detección de Bordes: Proporciona bordes más delgados y continuos en comparación con el Laplaciano.
# * Direccionalidad: Detecta bordes en diferentes direcciones y proporciona una mejor precisión en la ubicación de los bordes.
# * Ruido: Menos sensible al ruido debido al filtrado gaussiano previo.
#
# Comparación:
#
# * Precisión: El algoritmo de Canny generalmente proporciona resultados más precisos y robustos que el kernel Laplaciano, ya que realiza un procesamiento más complejo y utiliza técnicas avanzadas como la supresión de no máximos y la histeresis.
# * Complejidad: Canny es más complejo en términos de cálculo y parámetros, mientras que el kernel Laplaciano es más simple pero menos robusto.
# * Sensible al Ruido: El Laplaciano puede ser más sensible al ruido, mientras que Canny incluye un paso de suavizado para mitigar esto.
#
# ### Resumen:
#
# Kernel Laplaciano: Utiliza una segunda derivada para detectar bordes, simple y directo, pero puede ser sensible al ruido.
# Algoritmo de Canny: Utiliza un enfoque más completo con filtrado, gradientes, supresión de no máximos y histeresis, proporcionando bordes más precisos y menos afectados por el ruido.
# Recursos Adicionales
# Para entender mejor ambos enfoques, puedes consultar recursos adicionales y documentación sobre procesamiento de imágenes y detección de bordes en libros de visión por computadora o tutoriales en línea.
